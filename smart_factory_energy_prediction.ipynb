# %% [markdown]
# # Smart Factory Energy Prediction Challenge
#
# **Author**: Karan Kumar
# **Date**: May 27, 2025
# **Objective**: Develop a robust regression model to predict equipment energy consumption

# %%
# Import libraries and run complete analysis
from main import main

# Run the complete pipeline
pipeline, results = main()

print("Analysis completed successfully!")
